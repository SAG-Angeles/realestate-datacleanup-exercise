# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
# ...

# %%
ds.describe()
# Out:
#          Unnamed: 0  id_realEstates  phone_realEstate         rooms  \
# count  15335.000000    1.533500e+04      1.454100e+04  14982.000000
# mean    7668.000000    1.524371e+08      9.143423e+08      3.231611
# std     4426.977524    2.277286e+06      7.516036e+06      1.393106
# min        1.000000    1.221584e+08      8.762742e+08      1.000000
# 25%     3834.500000    1.519456e+08      9.113649e+08      2.000000
# 50%     7668.000000    1.532413e+08      9.121841e+08      3.000000
# 75%    11501.500000    1.538105e+08      9.148904e+08      4.000000
# max    15335.000000    1.540033e+08      9.887761e+08     30.000000
#
#           bathrooms        surface         price  countryId  level1Id  \
# count  14990.000000   14085.000000  1.533500e+04    15335.0   15335.0
# mean       2.150233     196.916436  4.773036e+05        0.0       0.0
# std        1.292079    2182.758313  5.912942e+05        0.0       0.0
# min        1.000000      15.000000  0.000000e+00        0.0       0.0
# ...

# %%
print(ds.index)
# Out:
# RangeIndex(start=0, stop=15335, step=1)

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
precio_max = ds['price'].max()
info_casa = ds[ds['price']==precio_max]
print(precio_max)
# Out:
# 8500000

# %%
precio = info_casa['price'].values

# %%
direccion = info_casa['address'].values
print(direccion)
# Out:
# ['El Escorial']

# %%
print(f"La casa con dirección en calle {direccion}, es la más cara y su precio es de {precio} USD")
# Out:
# La casa con dirección en calle ['El Escorial'], es la más cara y su precio es de [8500000] USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
precio_min = ds['price'].min()

# %%
info_casa = ds[ds['price'] == precio_min]

# %%
precio = info_casa['price'].values
print(precio_min)
# Out:
# 0

# %%
# obtener una casa que no sea precio 0

precios_validos = ds.query("price > 0")

precio_min = precios_validos['price'].min()

info_casa = precios_validos.query(f"price == {precio_min}")

precio = info_casa['price'].values

print(precio_min)
# Out:
# 600

# %%
info_casa = precios_validos.query(f"price == {precio_min}")
fila = info_casa.index.tolist()
print("Fila(s) donde está:", fila)
# Out:
# Fila(s) donde está: [7491]

# %%
print(ds.iloc[7491])
# Out:
# Unnamed: 0                                                       7492
# id_realEstates                                              153977752
# isNew                                                           False
# realEstate_name                                       redpiso coslada
# phone_realEstate                                          910759552.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             3.0
# bathrooms                                                         1.0
# surface                                                          80.0
# price                                                             600
# date                                             2019-12-24T12:56:00Z
# description         REDPISO COSLADA alquila vivienda en Ciudad 70,...
# address                                               Berlin, Coslada
# ...

# %%
direccion = info_casa['address'].values
print(direccion)
# Out:
# ['Berlin, Coslada']

# %%
precio = info_casa['price'].values
print(precio_min)
# Out:
# 600

# %%
print(f"La casa con dirección en calle {direccion}, es la más barata y su precio es de {precio} USD")
# Out:
# La casa con dirección en calle ['Berlin, Coslada'], es la más barata y su precio es de [600] USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
casa_grande = ds['surface'].max()
info_casa = ds[ds['surface'] == casa_grande]
print(casa_grande)
# Out:
# 249000.0

# %%
Grande = info_casa['surface'].values
print(Grande)
# Out:
# [249000.]

# %%
direccion = info_casa['address'].values
print(direccion)
# Out:
# ['Sevilla la Nueva']

# %%
print(f"La casa más grande está ubicada en {direccion[0]} y su superficie es de {Grande[0]} metros")
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros

# %%
casa_chica = ds['surface'].min()
info_casita = ds[ds['surface'] == casa_chica]
print(casa_chica)
# Out:
# 15.0

# %%
direccion = info_casita['address'].values
print(direccion)
# Out:
# ['Calle Amparo,  Madrid Capital']

# %%
print(f"La casa más chica está ubicada en {direccion[0]} y su superficie es de {casa_chica} metros")
# Out:
# La casa más chica está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
poblacion = ds['level5'].max()
info_poblacion = ds[ds['level5Id'] == poblacion]


poblaciones = ds['level5'].unique()
print(f"Numero de polaciones:", ds['level5'].nunique())

# Imprimir como cadena separada por comas
print(', '.join(poblaciones))
# Out:
# Numero de polaciones: 168
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
#1. Verificar si hay algún NA en el dataset
hay_nas = ds.isna().any().any()
print(hay_nas)

# 2. Si hay NAs, mostrar el conteo por columna
if hay_nas:
    print([ds.isna().sum() > 0])
# Out:
# True
# [Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
columnas_vacias = ds.columns[ds.isna().all()]
print("Columnas completamente vacías:",(columnas_vacias.tolist()))
# Out:
# Columnas completamente vacías: ['zipCode', 'customZone']

# %%
#anteriormente encontro que las Columnas completamente vacías fueron: ['zipCode', 'customZone'] 
# voy a eliminar con la funcion .drop :(
ds.drop(columns=columnas_vacias)
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']
media_precio = arroyomolinos['price'].mean()

print(f"Media de precios en Arroyomolinos (Madrid): {media_precio}")
# Out:
# Media de precios en Arroyomolinos (Madrid): 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

precios = arroyomolinos['price'].dropna()

# Trazar el histograma

plt.hist(precios)
plt.title('Histograma de precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
print(f"Esta zona, tienen un rango de precios que va desde 200000 hasta los 400000")
# Out:
# Esta zona, tienen un rango de precios que va desde 200000 hasta los 400000

# %% [markdown]
# Los precios de esta zona en especifico en este Histograma de precios en Arroyomolinos (Madrid) muestra que la mayoría de los inmuebles se concentran en un rango de precios que va de unos 180000 a los 400000 aprox.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
valdemorillo = ds[ds['level5'] == 'Valdemorillo']
galapagar = ds[ds['level5'] == 'Galapagar']


media_valdemorillo = valdemorillo['price'].mean()
media_galapagar = galapagar['price'].mean()


print(f"Precio promedio en Valdemorillo: {media_valdemorillo}")
print(f"Precio promedio en Galapagar: {media_galapagar}")
# Out:
# Precio promedio en Valdemorillo: 363860.2931034483
# Precio promedio en Galapagar: 360063.20238095237

# %% [markdown]
# Aunque ambas entidades se aproximan en promedio de precios, es notable una diferencia de 3797 lo que se puede concluir que una de estas poblaciones precenta algunas cracteristicas de ventaja en el sector inmobiliario.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ppm2_valdemorillo = (valdemorillo['price'] / valdemorillo['surface']).mean()
ppm2_galapagar = (galapagar['price'] / galapagar['surface']).mean()


print(f"Precio promedio por m² en Valdemorillo: {ppm2_valdemorillo:}")
print(f"Precio promedio por m² en Galapagar: {ppm2_galapagar:}")
# Out:
# Precio promedio por m² en Valdemorillo: 1317.9502109024986
# Precio promedio por m² en Galapagar: 1606.3240303094024

# %%
ds['pps'] = ds['price'] / ds['surface']

ds.describe()
# Out:
#          Unnamed: 0  id_realEstates  phone_realEstate         rooms  \
# count  15335.000000    1.533500e+04      1.454100e+04  14982.000000
# mean    7668.000000    1.524371e+08      9.143423e+08      3.231611
# std     4426.977524    2.277286e+06      7.516036e+06      1.393106
# min        1.000000    1.221584e+08      8.762742e+08      1.000000
# 25%     3834.500000    1.519456e+08      9.113649e+08      2.000000
# 50%     7668.000000    1.532413e+08      9.121841e+08      3.000000
# 75%    11501.500000    1.538105e+08      9.148904e+08      4.000000
# max    15335.000000    1.540033e+08      9.887761e+08     30.000000
#
#           bathrooms        surface         price  countryId  level1Id  \
# count  14990.000000   14085.000000  1.533500e+04    15335.0   15335.0
# mean       2.150233     196.916436  4.773036e+05        0.0       0.0
# std        1.292079    2182.758313  5.912942e+05        0.0       0.0
# min        1.000000      15.000000  0.000000e+00        0.0       0.0
# ...

# %% [markdown]
# En Valdemorillo el precio promedio por metro cuadrado es ligeramente más alto
# que en Galapagar, lo que sugiere que Valdemorillo podría ser una zona más
# exclusiva o tener características que aumentan el valor inmobiliario
# en comparación con Galapagar.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.scatter(ds['surface'], ds['price'])
plt.title('Relación entre superficie y precio')
plt.xlabel('Superficie (m²)')
plt.ylabel('Precio')
plt.grid(True)
plt.show()

# %% [markdown]
# El análisis revela una tendencia general: a mayor superficie, mayor precio, aunque no es una relación estrictamente lineal. Propiedades con tamaños similares pueden presentar precios muy diferentes, lo que indica una variabilidad considerable en el precio por metro cuadrado (pps)

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone', 'pps'],
#       dtype='object')

# %%
num_bienes = ds['realEstate_name'].nunique()
print(f"El numero de bienes raices es: {num_bienes}")
# Out:
# El numero de bienes raices es: 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
conteo = ds['level5'].value_counts()
poblacion_max = conteo.idxmax()
cantidad_max = conteo.max()

print(f"La población con más casas es: {poblacion_max}, con {cantidad_max} propiedades")
# Out:
# La población con más casas es:  Madrid Capital, con 6643 propiedades

# %% [markdown]
# no existe una columma o un indice que indique el numero de poblacion.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

ds_sur = ds[ds['level5'].isin(cinturon_sur)]

print(ds_sur.head())
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
medianas = ds_sur.groupby('level5')['price'].median().sort_values()
plt.bar(medianas.index, medianas.values, color='lightgreen', edgecolor='purple')
plt.title('Mediana de precios por población (Cinturón Sur de Madrid)')
plt.xlabel('Población')
plt.ylabel('Mediana de precio')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# El gráfico muestra la mediana de precios de las propiedades en cuatro municipios del cinturón sur de Madrid. en la cual vamos de menor a mayor y en las cuales Getafe promedia en lo mas alto.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

ds_sur = ds[ds['level5'].isin(cinturon_sur)]

print("Precio")
print("Media:", ds_sur['price'].mean())
print("Varianza:", ds_sur['price'].var())

print("\nHabitaciones")
print("Media:", ds_sur['rooms'].mean())
print("Varianza:", ds_sur['rooms'].var())

print("\nSuperficie")
print("Media:", ds_sur['surface'].mean())
print("Varianza:", ds_sur['surface'].var())

print("\nBaños")
print("Media:", ds_sur['bathrooms'].mean())
print("Varianza:", ds_sur['bathrooms'].var())
# Out:
# Precio
# Media: 223094.48070562293
# Varianza: 14921367508.04902
#
# Habitaciones
# Media: 3.0177383592017737
# Varianza: 0.7188858892927542
#
# Superficie
# Media: 111.75222363405337
# Varianza: 4263.051760316337
#
# Baños
# Media: 1.633221850613155
# Varianza: 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
mas_caras = ds_sur.loc[ds_sur.groupby('level5')['price'].idxmax()]

print(mas_caras[['level5', 'address', 'price']])
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']


ds_sur = ds[ds['level5'].isin(cinturon_sur)]

# Crear gráfico
plt.figure()


for poblacion in cinturon_sur:
    precios = ds_sur[ds_sur['level5'] == poblacion]['price']
    precios_norm = (precios - precios.mean()) / precios.std()
    plt.hist(precios_norm, bins=20, alpha=0.5, label=poblacion)

# Mostrar gráfico
plt.legend()
plt.title("Precios normalizados por población")
plt.xlabel("Precio normalizado")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# El gráfico muestra la distribución de precios normalizados (Z-score) para las cuatro poblaciones del cinturón sur de Madrid. Al normalizar, cada población tiene media 0 y desviación estándar 1, lo que permite comparar la forma de las distribuciones sin que influya el nivel absoluto de precios.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
cinturon_sur2 = ['Getafe', 'Alcorcón']

ds_sur2 = ds[ds['level5'].isin(cinturon_sur2)]
ds_sur['pps'] = ds_sur2['price'] / ds_sur2['surface']



print(ds_sur2.head())
# Out:
#      Unnamed: 0  id_realEstates  isNew                  realEstate_name  \
# 85           86       153152077  False          sinergical inmobiliaria
# 109         110       153586414  False  area uno asesores inmobiliarios
# 169         170       153920011  False                     grupo tizona
# 232         233       152842726  False              aljada inmobiliaria
# 233         234       152842686  False              aljada inmobiliaria
#
#      phone_realEstate                                       url_inmueble  \
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 169       911226046.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 232       916355578.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
# 233       916355578.0  https://www.fotocasa.es/es/comprar/vivienda/sa...
#
#      rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# ...

# %%
media_pps = ds_sur2.groupby('level5')['pps'].mean()

print(media_pps[['Getafe', 'Alcorcón']])
# Out:
# level5
# Getafe      2066.314949
# Alcorcón    2239.302480
# Name: pps, dtype: float64

# %% [markdown]
# Getafe cuenta con una media mas baja a comparicon de Alcorcon, se pordia decir que una forma de explicar es la diferencia de las casas esclusivas. las que determinan este resultado.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
ds_sur = ds[ds['level5'].isin(cinturon_sur)]

fig, axs = plt.subplots(2, 2, figsize=(10, 8))


for i, poblacion in enumerate(cinturon_sur):
    datos = ds_sur[ds_sur['level5'] == poblacion]
    fila = i // 2
    columna = i % 2
    axs[fila][columna].scatter(datos['surface'], datos['price'], alpha=0.5)
    axs[fila][columna].set_title(poblacion)
    axs[fila][columna].set_xlabel('Superficie (m²)')
    axs[fila][columna].set_ylabel('Precio')


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
cinturon_sur = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

ds_sur = ds[ds['level5'].isin(cinturon_sur)]

print(ds_sur[['level5', 'latitude', 'longitude']].head())

coordenadas = ds_sur[['latitude', 'longitude']].dropna().to_dict('records')


print(coordenadas)
# Out:
#           level5          latitude          longitude
# 1    Fuenlabrada          40,28674           -3,79351
# 3    Fuenlabrada  40,2853785786438  -3,79508142135624
# 85      Alcorcón          40,35059           -3,82693
# 94       Leganés          40,31933           -3,77574
# 109     Alcorcón        40,3313411         -3,8313868
# ...
